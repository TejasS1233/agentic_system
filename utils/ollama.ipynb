# %% [markdown]
# How to run:
#
# Download Jupyter and Colab extension from vscode store
#
# Then connect the kernel of this nb to Colab
#
# Then run

# %%
# !sudo apt update
# !sudo apt install -y pciutils zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# %pip install pyngrok ollama
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# ...

# %%
import threading
import subprocess
import time
import os
from pyngrok import ngrok, conf

def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])


thread = threading.Thread(target=run_ollama_serve)
thread.start()

time.sleep(5)

# %%
os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"
os.environ["OLLAMA_ORIGINS"] = "*"

# !pkill ollama

subprocess.Popen(["ollama", "serve"])
print("Restarting Ollama with OLLAMA_ORIGINS='*'...")
time.sleep(5)

print("Enter your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken")
conf.get_default().auth_token = "31BwP90LBnQUNnqhKKniU6a8oCy_7BcTCGyXu3ZZnKn7S2eJG"

ngrok.kill()

public_url = ngrok.connect("11434", "http").public_url

print("---")
print(f" * YOUR OLLAMA URL: {public_url}")
print("---")
# Out:
# Restarting Ollama with OLLAMA_ORIGINS='*'...
# Enter your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
# ---
#  * YOUR OLLAMA URL: https://76ffebcb3cd2.ngrok-free.app
# ---

# %%
# !ollama pull qwen2.5-coder:latest
# !ollama list
# Out:
# NAME                    ID              SIZE      MODIFIED
# qwen2.5-coder:latest    dae161e27b0e    4.7 GB    Less than a second ago
