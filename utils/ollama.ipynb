# %% [markdown]
# 0. **How to run --->**
# 1. **Download Jupyter and Colab extension from vscode store**
# 2. **Then connect the kernel of this nb to Colab**
# 3. **Then run all cells**

# %%
# !sudo apt update
# !sudo apt install -y pciutils zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# %pip install pyngrok ollama
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.8 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]3m
# ...

# %%
import threading
import subprocess
import time
import os
from pyngrok import ngrok, conf


def run_ollama_serve():
    subprocess.Popen(["ollama", "serve"])


thread = threading.Thread(target=run_ollama_serve)
thread.start()

time.sleep(5)

# %%
os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"
os.environ["OLLAMA_ORIGINS"] = "*"

# !pkill ollama

subprocess.Popen(["ollama", "serve"])
print("Restarting Ollama with OLLAMA_ORIGINS='*'...")
time.sleep(5)

print(
    "Enter your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken"
)
conf.get_default().auth_token = "31BwP90LBnQUNnqhKKniU6a8oCy_7BcTCGyXu3ZZnKn7S2eJG"

ngrok.kill()

public_url = ngrok.connect("11434", "http").public_url

print("---")
print(f" * YOUR OLLAMA URL: {public_url}")
print("---")
# Out:
# Restarting Ollama with OLLAMA_ORIGINS='*'...
# Enter your authtoken from https://dashboard.ngrok.com/get-started/your-authtoken
# ---
#  * YOUR OLLAMA URL: https://314f-136-110-60-238.ngrok-free.app
# ---

# %%
# !ollama signin
# Out:
# You need to be signed in to Ollama to run Cloud models.
#
# To sign in, navigate to:
#     https://ollama.com/connect?name=79d7fe18b3c2&key=c3NoLWVkMjU1MTkgQUFBQUMzTnphQzFsWkRJMU5URTVBQUFBSU9xTmJqamROUzVIOURFeDBQRFBSZ09pVXNRWEkvV21PVUZ0Q1JTSlQ3SEI

# %%
# !ollama pull qwen2.5-coder:7b
# !ollama pull qwen2.5-coder:14b
# !ollama list
# Out:
# NAME                 ID              SIZE      MODIFIED
# qwen2.5-coder:14b    9ec8897f747e    9.0 GB    Less than a second ago
# qwen2.5-coder:7b     dae161e27b0e    4.7 GB    About a minute ago

# %%
# !ollama ps
# Out:
# NAME    ID    SIZE    PROCESSOR    CONTEXT    UNTIL

# %%
import os
from ollama import Client

client = Client(
    host="https://314f-136-110-60-238.ngrok-free.app",
    headers={"ngrok-skip-browser-warning": "true"}
)

messages = [
  {
    'role': 'user',
    'content': 'Why is TejasTG1233 the best?',
  },
]

for part in client.chat('qwen2.5-coder:7b', messages=messages, stream=True):
  print(part['message']['content'], end='', flush=True)
# Out:
# TejasTG1233 is an advanced model of a gas turbine designed for various applications in power generation and industrial processes. While I don't have specific information about this particular model, it's generally true that gas turbines are favored due to their high efficiency, reliability, and ability to operate at high temperatures and pressures.
#
# Gas turbines like TejasTG1233 are often preferred because they can convert a significant portion of the energy in natural gas or other fossil fuels into electrical power. This makes them an efficient choice for generating electricity on large scales, particularly in regions with abundant gas reserves.
#
# Moreover, modern gas turbines such as this one may incorporate advanced technologies like aerodynamics, materials science, and control systems to enhance performance, reduce emissions, and improve overall efficiency.
#
# ...
